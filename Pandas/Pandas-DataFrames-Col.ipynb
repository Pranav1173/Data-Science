# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
myindex = ['MH', 'KN', 'TN', 'WB']

# %%
print(mydata)
# Out:
# [[95 11 81]
#  [70 63 87]
#  [75  9 77]
#  [40  4 63]]

# %%
attr = ['GDP', 'IT', 'REL']

# %%
df = pd.DataFrame(mydata)

# %%
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
pndf = pd.DataFrame(mydata, myindex, attr)

# %%
pndf
# Out:
#     GDP  IT  REL
# MH   95  11   81
# KN   70  63   87
# TN   75   9   77
# WB   40   4   63

# %%
pndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, MH to WB
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     4 non-null      int32
#  1   IT      4 non-null      int32
#  2   REL     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
df1 = pd.read_csv('example.csv')

# %%
df1
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
df2 = pd.read_csv('C:\\Users\\prana\\Jupyter\\Python\\IndiaData.csv')

# %%
df2
# Out:
#    countrycode country currency_unit  year       GDP  net population growth  \
# 0          IND   India  Indian Rupee  1979       NaN             682.995354
# 1          IND   India  Indian Rupee  1980  5.281000               0.023364
# 2          IND   India  Indian Rupee  1981  6.006000               0.023510
# 3          IND   India  Indian Rupee  1982  3.476000               0.023560
# 4          IND   India  Indian Rupee  1983  7.289000               0.023475
# 5          IND   India  Indian Rupee  1984  3.821000               0.023224
# 6          IND   India  Indian Rupee  1985  5.254000               0.022856
# 7          IND   India  Indian Rupee  1986  4.777000               0.022458
# 8          IND   India  Indian Rupee  1987  3.965000               0.022079
# 9          IND   India  Indian Rupee  1988  9.628000               0.021700
# 10         IND   India  Indian Rupee  1989  5.947000               0.021333
# ...

# %%
df2.columns
# Out:
# Index(['countrycode', 'country', 'currency_unit', 'year', 'GDP',
#        'net population growth', 'CPI', 'employment rate', 'labsh', 'xr',
#        'pl_gdpo', 'csh_c', 'csh_i', 'csh_g', 'csh_x', 'csh_m', 'csh_r', 'pl_c',
#        'pl_i', 'pl_g', 'pl_x', 'pl_m', 'pl_n', 'pl_k', 'GDP.1'],
#       dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=41, step=1)

# %%
df2.head(10)
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
# 5         IND   India  Indian Rupee  1984  3.821               0.023224
# 6         IND   India  Indian Rupee  1985  5.254               0.022856
# 7         IND   India  Indian Rupee  1986  4.777               0.022458
# 8         IND   India  Indian Rupee  1987  3.965               0.022079
# 9         IND   India  Indian Rupee  1988  9.628               0.021700
#
#          CPI  employment rate     labsh        xr  ...     csh_m     csh_r  \
# 0        NaN       256.839111  0.709059  8.125791  ... -0.027104 -0.063782
# ...

# %%
df2.describe().transpose()
# Out:
#                        count         mean         std          min  \
# year                    41.0  1999.000000   11.979149  1979.000000
# GDP                     40.0     5.868666    1.854317     1.057000
# net population growth   41.0    16.675493  106.663221     0.010184
# CPI                     40.0     7.902614    3.043830     2.490887
# employment rate         41.0     6.263619   40.111651    -0.017225
# labsh                   41.0     0.010039    0.113658    -0.065614
# xr                      41.0     0.254593    1.262023    -0.087370
# pl_gdpo                 41.0     0.021244    0.065271    -0.142609
# csh_c                   41.0     0.015728    0.106977    -0.044591
# csh_i                   41.0     0.018882    0.081396    -0.169636
# csh_g                   41.0    -0.020405    0.059846    -0.100470
# csh_x                   41.0     0.019582    0.080035    -0.132554
# csh_m                   41.0     0.036352    0.156437    -0.227116
# ...

# %%
arr = np.arange(0,25,1).reshape(5,5).transpose()

# %%
print(arr)
# Out:
# [[ 0  5 10 15 20]
#  [ 1  6 11 16 21]
#  [ 2  7 12 17 22]
#  [ 3  8 13 18 23]
#  [ 4  9 14 19 24]]

# %%
df2.head(7)
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
# 5         IND   India  Indian Rupee  1984  3.821               0.023224
# 6         IND   India  Indian Rupee  1985  5.254               0.022856
#
#          CPI  employment rate     labsh        xr  ...     csh_m     csh_r  \
# 0        NaN       256.839111  0.709059  8.125791  ... -0.027104 -0.063782
# 1  11.346060         0.007102  0.038942 -0.032347  ...  0.311639 -0.235969
# 2  13.112550         0.004508 -0.027032  0.101181  ...  0.171218 -0.391245
# 3   7.890750         0.004125 -0.013325  0.092003  ... -0.227116  0.640088
# ...

# %%
col = ['year', 'GDP']

# %%
df2[col]
# Out:
#     year       GDP
# 0   1979       NaN
# 1   1980  5.281000
# 2   1981  6.006000
# 3   1982  3.476000
# 4   1983  7.289000
# 5   1984  3.821000
# 6   1985  5.254000
# 7   1986  4.777000
# 8   1987  3.965000
# 9   1988  9.628000
# 10  1989  5.947000
# 11  1990  5.534000
# 12  1991  1.057000
# 13  1992  5.482000
# 14  1993  4.750000
# 15  1994  6.659000
# 16  1995  7.575000
# 17  1996  7.550000
# 18  1997  4.050000
# 19  1998  6.184000
# 20  1999  8.463000
# 21  2000  3.975000
# 22  2001  4.944000
# 23  2002  3.907000
# 24  2003  7.944000
# 25  2004  7.849000
# 26  2005  9.285000
# 27  2006  9.264000
# 28  2007  9.801000
# 29  2008  6.013703
# 30  2009  4.701769
# 31  2010  6.377626
# 32  2011  6.169784
# 33  2012  6.030051
# 34  2013  5.557264
# 35  2014  5.006668
# 36  2015  4.876322
# 37  2016  5.033069
# 38  2017  5.069786
# 39  2018  5.174292
# 40  2019  5.019288

# %%
0.5 * (df2['GDP'] + df2['GDP.1'])
# Out:
# 0          NaN
# 1     5.281000
# 2     6.006000
# 3     3.476000
# 4     7.289000
# 5     3.821000
# 6     5.254000
# 7     4.777000
# 8     3.965000
# 9     9.628000
# 10    5.947000
# 11    5.534000
# 12    1.057000
# 13    5.482000
# 14    4.750000
# 15    6.659000
# 16    7.575000
# 17    7.550000
# 18    4.050000
# 19    6.184000
# 20    8.463000
# 21    3.975000
# 22    4.944000
# 23    3.907000
# 24    7.944000
# 25    7.849000
# 26    9.285000
# 27    9.264000
# 28    9.801000
# 29    6.013703
# 30    4.701769
# 31    6.377626
# 32    6.169784
# 33    6.030051
# 34    5.557264
# 35    5.006668
# 36    4.876322
# 37    5.033069
# 38    5.069786
# 39    5.174292
# 40    5.019288
# dtype: float64

# %%
df2['Percent_max'] = 100 * df2['GDP'] / df2['GDP'].max()

# %%
df2.head()
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
#
#         CPI  employment rate     labsh        xr  ...     csh_r      pl_c  \
# 0       NaN       256.839111  0.709059  8.125791  ... -0.063782  0.190954
# 1  11.34606         0.007102  0.038942 -0.032347  ... -0.235969  0.221119
# 2  13.11255         0.004508 -0.027032  0.101181  ... -0.391245  0.024342
# 3   7.89075         0.004125 -0.013325  0.092003  ...  0.640088  0.022520
# 4  11.86807         0.003785  0.016143  0.068086  ... -0.435581  0.036162
#
#        pl_i      pl_g      pl_x      pl_m      pl_n      pl_k  GDP.1  \
# ...

# %%
df2['Percent_max'] = np.round( df2['GDP'] / df2['GDP'].max(), decimals = 2)

# %%
df2.head()
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
#
#         CPI  employment rate     labsh        xr  ...     csh_r      pl_c  \
# 0       NaN       256.839111  0.709059  8.125791  ... -0.063782  0.190954
# 1  11.34606         0.007102  0.038942 -0.032347  ... -0.235969  0.221119
# 2  13.11255         0.004508 -0.027032  0.101181  ... -0.391245  0.024342
# 3   7.89075         0.004125 -0.013325  0.092003  ...  0.640088  0.022520
# 4  11.86807         0.003785  0.016143  0.068086  ... -0.435581  0.036162
#
#        pl_i      pl_g      pl_x      pl_m      pl_n      pl_k  GDP.1  \
# ...

# %%
df2['Percent_max'] *=100

# %%
df2.head()
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
#
#         CPI  employment rate     labsh        xr  ...     csh_r      pl_c  \
# 0       NaN       256.839111  0.709059  8.125791  ... -0.063782  0.190954
# 1  11.34606         0.007102  0.038942 -0.032347  ... -0.235969  0.221119
# 2  13.11255         0.004508 -0.027032  0.101181  ... -0.391245  0.024342
# 3   7.89075         0.004125 -0.013325  0.092003  ...  0.640088  0.022520
# 4  11.86807         0.003785  0.016143  0.068086  ... -0.435581  0.036162
#
#        pl_i      pl_g      pl_x      pl_m      pl_n      pl_k  GDP.1  \
# ...

# %%
#removing column
df2.drop('Percent_max',axis = 1)
# Out:
#    countrycode country currency_unit  year       GDP  net population growth  \
# 0          IND   India  Indian Rupee  1979       NaN             682.995354
# 1          IND   India  Indian Rupee  1980  5.281000               0.023364
# 2          IND   India  Indian Rupee  1981  6.006000               0.023510
# 3          IND   India  Indian Rupee  1982  3.476000               0.023560
# 4          IND   India  Indian Rupee  1983  7.289000               0.023475
# 5          IND   India  Indian Rupee  1984  3.821000               0.023224
# 6          IND   India  Indian Rupee  1985  5.254000               0.022856
# 7          IND   India  Indian Rupee  1986  4.777000               0.022458
# 8          IND   India  Indian Rupee  1987  3.965000               0.022079
# 9          IND   India  Indian Rupee  1988  9.628000               0.021700
# 10         IND   India  Indian Rupee  1989  5.947000               0.021333
# ...

# %%
df2.drop(0)
# Out:
#    countrycode country currency_unit  year       GDP  net population growth  \
# 1          IND   India  Indian Rupee  1980  5.281000               0.023364
# 2          IND   India  Indian Rupee  1981  6.006000               0.023510
# 3          IND   India  Indian Rupee  1982  3.476000               0.023560
# 4          IND   India  Indian Rupee  1983  7.289000               0.023475
# 5          IND   India  Indian Rupee  1984  3.821000               0.023224
# 6          IND   India  Indian Rupee  1985  5.254000               0.022856
# 7          IND   India  Indian Rupee  1986  4.777000               0.022458
# 8          IND   India  Indian Rupee  1987  3.965000               0.022079
# 9          IND   India  Indian Rupee  1988  9.628000               0.021700
# 10         IND   India  Indian Rupee  1989  5.947000               0.021333
# 11         IND   India  Indian Rupee  1990  5.534000               0.020978
# ...

# %%
df2.head()
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
#
#         CPI  employment rate     labsh        xr  ...     csh_r      pl_c  \
# 0       NaN       256.839111  0.709059  8.125791  ... -0.063782  0.190954
# 1  11.34606         0.007102  0.038942 -0.032347  ... -0.235969  0.221119
# 2  13.11255         0.004508 -0.027032  0.101181  ... -0.391245  0.024342
# 3   7.89075         0.004125 -0.013325  0.092003  ...  0.640088  0.022520
# 4  11.86807         0.003785  0.016143  0.068086  ... -0.435581  0.036162
#
#        pl_i      pl_g      pl_x      pl_m      pl_n      pl_k  GDP.1  \
# ...

# %%
df2 = df2.drop('Percent_max',axis = 1)

# %%
df2.head()
# Out:
#   countrycode country currency_unit  year    GDP  net population growth  \
# 0         IND   India  Indian Rupee  1979    NaN             682.995354
# 1         IND   India  Indian Rupee  1980  5.281               0.023364
# 2         IND   India  Indian Rupee  1981  6.006               0.023510
# 3         IND   India  Indian Rupee  1982  3.476               0.023560
# 4         IND   India  Indian Rupee  1983  7.289               0.023475
#
#         CPI  employment rate     labsh        xr  ...     csh_m     csh_r  \
# 0       NaN       256.839111  0.709059  8.125791  ... -0.027104 -0.063782
# 1  11.34606         0.007102  0.038942 -0.032347  ...  0.311639 -0.235969
# 2  13.11255         0.004508 -0.027032  0.101181  ...  0.171218 -0.391245
# 3   7.89075         0.004125 -0.013325  0.092003  ... -0.227116  0.640088
# 4  11.86807         0.003785  0.016143  0.068086  ...  0.568956 -0.435581
#
#        pl_c      pl_i      pl_g      pl_x      pl_m      pl_n      pl_k  GDP.1
# ...

# %%
df2.sort_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 help(pd.sort_by)
#
# AttributeError: module 'pandas' has no attribute 'sort_by'
