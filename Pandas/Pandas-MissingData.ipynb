# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('classg.csv')

# %%
df.head(3)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09      NaN     51.48  52.50
# 1       8       95.05    105.49     67.5       NaN  68.33
# 2       8       83.70     83.17     30.0     63.15  48.89

# %%
df.isnull()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False     True     False  False
# 1    False       False     False    False      True  False
# 2    False       False     False    False     False  False
# 3    False       False      True    False     False  False
# 4    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 94   False       False     False    False     False  False
# 95   False       False     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [99 rows x 6 columns]

# %%
df[df['Final'].notnull()]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09      NaN     51.48  52.50
# 1        8       95.05    105.49    67.50       NaN  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [96 rows x 6 columns]

# %%
df.dropna(thresh = 5)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09      NaN     51.48  52.50
# 1        8       95.05    105.49    67.50       NaN  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [97 rows x 6 columns]

# %%
df.fillna(df.mean())
# Out:
#     Prefix  Assignment    Tutorial    Midterm    TakeHome  Final
# 0        5       57.14   34.090000  67.967263   51.480000  52.50
# 1        8       95.05  105.490000  67.500000   80.253871  68.33
# 2        8       83.70   83.170000  30.000000   63.150000  48.89
# 3        7       81.22   89.791809  49.380000  105.930000  80.56
# 4        8       91.32   93.640000  95.000000  107.410000  73.89
# ..     ...         ...         ...        ...         ...    ...
# 94       8       96.73  103.710000  45.000000   93.520000  61.94
# 95       7       85.34   80.540000  41.250000   93.700000  39.72
# 96       8       89.94  102.770000  87.500000   90.740000  87.78
# 97       7       95.60   76.130000  66.250000   99.810000  85.56
# 98       8       63.40   97.370000  73.120000   72.780000  77.22
#
# [99 rows x 6 columns]

# %% [markdown]
# groupby() Demonstration

# %%
Data = [['A',10],
       ['C',13],
       ['C',51],
       ['B',69],
       ['A',12],
       ['B',72]]

# %%
Col = ['Category','Data Value']

# %%
df1 = pd.DataFrame(data = Data, columns = Col)

# %%
df1
# Out:
#   Category  Data Value
# 0        A          10
# 1        C          13
# 2        C          51
# 3        B          69
# 4        A          12
# 5        B          72

# %%
df1.set_index('Category')
# Out:
#           Data Value
# Category
# A                 10
# C                 13
# C                 51
# B                 69
# A                 12
# B                 72

# %%
daf = pd.read_csv('example.csv')

# %%
daf.head()
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
daf['Country'].value_counts()
# Out:
# Country
# Benin                           3
# Sweden                          3
# Northern Mariana Islands        2
# United States Virgin Islands    2
# Eritrea                         2
#                                ..
# Philippines                     1
# Christmas Island                1
# Czech Republic                  1
# Romania                         1
# Anguilla                        1
# Name: count, Length: 84, dtype: int64

# %%
daf
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
daf.groupby('Founded').sum()['Number of employees']
# Out:
# Founded
# 1970    13915
# 1971    14521
# 1972    26695
# 1973     2273
# 1974     2073
# 1975     2988
# 1976     5419
# 1978    11164
# 1980    11367
# 1981    14927
# 1982     6146
# 1984      769
# 1986    26363
# 1987    10808
# 1988    26611
# 1989     4558
# 1990    19019
# 1991    24185
# 1992     4914
# 1993    12045
# 1994     9995
# 1996     9666
# 1997    13648
# 1998     8744
# 1999    17249
# 2000     7012
# 2001     9219
# 2002     5259
# 2004      921
# 2005     1418
# 2006    14853
# 2008     6923
# 2009    11914
# 2010     1312
# 2011     5984
# 2012    21460
# 2013    10717
# 2014    25827
# 2015     4952
# 2016    17088
# 2017    12328
# 2018    10017
# 2020     5472
# 2021    23748
# Name: Number of employees, dtype: int64

# %% [markdown]
# MULTIINDEX

# %%
grp = daf.groupby(['Founded','Industry']).sum()['Number of employees']

# %%
grp.index
# Out:
# MultiIndex([(1970,                                  'Banking / Mortgage'),
#             (1970,                     'Computer Software / Engineering'),
#             (1970,                                     'Import / Export'),
#             (1971,                                     'Broadcast Media'),
#             (1971,                                   'Consumer Services'),
#             (1971,                                       'Public Safety'),
#             (1972,                                 'Facilities Services'),
#             (1972,                                         'Hospitality'),
#             (1972,                            'Outsourcing / Offshoring'),
#             (1972,                       'Primary / Secondary Education'),
#             (1972,                                            'Textiles'),
#             (1973,                   'International Trade / Development'),
# ...

# %%
grp.index.levels
# Out:
# FrozenList([[1970, 1971, 1972, 1973, 1974, 1975, 1976, 1978, 1980, 1981, 1982, 1984, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2020, 2021], ['Accounting', 'Alternative Dispute Resolution', 'Architecture / Planning', 'Arts / Crafts', 'Automotive', 'Banking / Mortgage', 'Broadcast Media', 'Building Materials', 'Business Supplies / Equipment', 'Capital Markets / Hedge Fund / Private Equity', 'Civic / Social Organization', 'Civil Engineering', 'Computer Software / Engineering', 'Construction', 'Consumer Electronics', 'Consumer Goods', 'Consumer Services', 'Education Management', 'Electrical / Electronic Manufacturing', 'Entertainment / Movie Production', 'Facilities Services', 'Farming', 'Financial Services', 'Food / Beverages', 'Gambling / Casinos', 'Glass / Ceramics / Concrete', 'Hospitality', 'Human Resources / HR', 'Import / Export', 'Individual / 
# ...

# %%
grp.loc[(1975,'Photography')]
# Out:
# 2988

# %%
grp.loc[[1975,2001]]
# Out:
# Founded  Industry
# 1975     Photography                      2988
# 2001     Luxury Goods / Jewelry           1746
#          Primary / Secondary Education    7473
# Name: Number of employees, dtype: int64

# %%
grp
# Out:
# Founded  Industry
# 1970     Banking / Mortgage                               1046
#          Computer Software / Engineering                  8480
#          Import / Export                                  4389
# 1971     Broadcast Media                                  4942
#          Consumer Services                                4292
#                                                           ...
# 2020     Utilities                                        2610
# 2021     Arts / Crafts                                    3527
#          Capital Markets / Hedge Fund / Private Equity    3816
#          Legal Services                                   7664
#          Legislative Office                               8741
# Name: Number of employees, Length: 100, dtype: int64
