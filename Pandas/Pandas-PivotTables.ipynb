# %%
import pandas as pd

# %%
df = pd.read_csv('mac-index-jan23.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0               Country iso_a3 currency_code  local_price  \
# 0           0  United Arab Emirates    ARE           AED        18.00
# 1           1             Argentina    ARG           ARS       980.00
# 2           2             Australia    AUS           AUD         7.25
#
#    dollar_ex  dollar_price  dollar_ppp    GDP_bigmac  dollar_valuation  \
# 0    3.67300      4.900626    3.358209  52265.827511            -8.570
# 1  184.69875      5.305937  182.835821   9657.655384            -1.009
# 2    1.41854      5.110888    1.352612  69300.231062            -4.648
#
#    euro_valuation  sterling_valuation  yen_valuation  yuan_valuation  \
# 0          -7.281               5.001         55.505          38.525
# 1           0.387              13.686         68.366          49.982
# 2          -3.303               9.506         62.177          44.469
#
#    dollar_adj_valuation  euro_adj_valuation  sterling_adj_valuation  \
# ...

# %%
df.pivot(index = 'dollar_price', columns = ['dollar_ppp','dollar_ex'], values = 'GDP_bigmac')
# Out:
# dollar_ppp    3.358209     182.835821    1.352612      0.914179      \
# dollar_ex      3.67300      184.69875     1.41854       1.70250
# dollar_price
# 1.842855               NaN          NaN           NaN           NaN
# 2.350966               NaN          NaN           NaN           NaN
# 2.469624               NaN          NaN           NaN           NaN
# 2.492077               NaN          NaN           NaN           NaN
# 2.533195               NaN          NaN           NaN           NaN
# 2.681753               NaN          NaN           NaN           NaN
# 2.718743               NaN          NaN           NaN           NaN
# 2.721931               NaN          NaN           NaN           NaN
# 2.847433               NaN          NaN           NaN           NaN
# 2.878120               NaN          NaN           NaN  12723.382041
# 2.899477               NaN          NaN           NaN           NaN
# 3.010151               NaN          NaN           NaN           NaN
# ...
